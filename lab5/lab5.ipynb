# %%
from pathlib import Path
from generate_lab5 import run_pipeline

summary = run_pipeline()
summary
# Out:
# {'variant': 17,
#  'alphabet_name': 'Казахские строчные буквы',
#  'font_name': 'Arial',
#  'font_size': 52,
#  'symbol_count': 42,
#  'csv_path': 'C:\\Users\\User\\vs\\oavi\\lab5\\features_variant17.csv',
#  'symbols_dir': 'C:\\Users\\User\\vs\\oavi\\lab5\\symbols_png',
#  'profiles_x_dir': 'C:\\Users\\User\\vs\\oavi\\lab5\\profiles_x_png',
#  'profiles_y_dir': 'C:\\Users\\User\\vs\\oavi\\lab5\\profiles_y_png',
#  'preview_path': 'C:\\Users\\User\\vs\\oavi\\lab5\\preview_png\\symbols_overview.png'}

# %%
from IPython.display import Image, display

base = Path.cwd()
display(Image(filename=str(base / "preview_png" / "symbols_overview.png")))

# %%
csv_path = Path(summary["csv_path"])
with csv_path.open("r", encoding="utf-8-sig") as f:
    for _ in range(5):
        print(f.readline().rstrip())
# Out:
# symbol;codepoint;width;height;mass_total;centroid_x;centroid_y;centroid_x_norm;centroid_y_norm;inertia_horizontal;inertia_vertical;inertia_horizontal_norm;inertia_vertical_norm;q1_top_left_mass;q1_top_left_specific_mass;q2_top_right_mass;q2_top_right_specific_mass;q3_bottom_left_mass;q3_bottom_left_specific_mass;q4_bottom_right_mass;q4_bottom_right_specific_mass
# а;u0430;33;35;393;16.651399;17.653944;0.520356;0.519234;25176.936387;20297.24173;0.055418;0.050436;67;0.246324;102;0.352941;107;0.371528;117;0.382353
# ә;u04d9;33;35;381;16.346457;17.091864;0.510827;0.502702;22431.784777;19960.267717;0.050931;0.051161;74;0.272059;91;0.314879;104;0.361111;112;0.366013
# б;u0431;34;46;492;15.900407;22.400407;0.481831;0.497787;60252.119919;30080.119919;0.060476;0.056142;143;0.365729;115;0.294118;119;0.304348;115;0.294118
# в;u0432;31;35;404;14.091584;17.10396;0.469719;0.503058;27149.633663;19805.611386;0.058133;0.054471;101;0.396078;91;0.334559;106;0.392593;106;0.368056
